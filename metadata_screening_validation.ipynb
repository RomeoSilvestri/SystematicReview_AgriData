# %%
import pandas as pd

folder_path = 'data/validation/'
file = folder_path + 'df_evaluated_validation.csv'

# %%
df_validation = pd.read_csv(file)

df_validation["Data Source"] = df_validation["Data Source Harmonized"]
df_validation.drop(columns=["Data Source Harmonized"], inplace=True)


df_validation
# Out:
#                                 DOI  \
# 0      10.1109/CVPR52688.2022.00296
# 1      10.1109/CVPR52729.2023.00238
# 2      10.1109/WACV57701.2024.00012
# 3    10.1109/MMSP55362.2022.9949464
# 4      10.1109/CVPR52733.2024.01386
# 5      10.1109/CVPR42600.2020.00986
# 6      10.1109/ICCV48922.2021.00782
# 7     10.1109/INSAI54028.2021.00029
# 8           10.1109/WACV.2019.00161
# 9           10.1109/CVPR.2019.00039
# 10   10.1109/MMSP53017.2021.9733638
# 11    10.1109/CVPRW63382.2024.00324
# 12       10.1109/TNSRE.2023.3317411
# 13      10.1109/ACCESS.2023.3316009
# 14        10.1109/TVCG.2023.3247092
# 15     10.1109/CVPR52688.2022.00323
# 16            10.1109/CVPRW.2017.16
# 17     10.1109/CVPR52733.2024.01744
# 18       10.1007/s10489-023-05166-3
# 19       10.1109/TCSVT.2023.3281413
# 20    10.1016/j.heliyon.2023.e21361
# 21          10.1145/3581783.3613774
# 22  10.1088/1742-6596/2632/1/012027
# 23         10.1109/TIP.2023.3331212
# 24             10.1155/2023/3649217
# 25       10.1109/TCSVT.2022.3143549
# 26     10.1007/978-3-031-18913-5_17
# 27     10.1007/978-3-031-19772-7_25
# 28     10.1007/978-3-031-04881-4_46
# 29          10.1145/3474085.3475438
# 30          10.1145/3453892.3461624
# 31     10.1109/ITME53901.2021.00048
# 32   10.1109/ICIP42928.2021.9506257
# 33   10.1109/VCIP53242.2021.9675430
# 34          10.1145/3394171.3421895
# 35          10.1145/3394171.3413560
# 36     10.1007/978-3-030-58577-8_14
# 37     10.1007/978-3-030-20876-9_10
# 38     10.1007/978-3-030-00767-6_12
# 39     10.1007/978-3-319-10599-4_36
# 40       10.1007/s00521-023-09068-w
# 41        10.1016/j.ins.2024.120347
# 42       10.1007/s40747-022-00892-6
# 43         10.1109/TIP.2024.3468870
# 44       10.1007/s10489-024-05349-6
# 45       10.1007/s10489-023-04613-5
# 46         10.1109/TIM.2024.3398072
# 47         10.1109/TIP.2024.3362135
# 48       10.1007/s11760-021-01890-w
# 49         10.1109/TCE.2024.3482560
# 50       10.1109/TPAMI.2022.3194311
# 51      10.1016/j.jvcir.2022.103625
# 52       10.1007/s11263-024-02146-z
# 53       10.1038/s41597-022-01188-7
# 54       10.1007/s11263-022-01695-5
# 55                10.3390/s19194129
# 56       10.1109/TCSVT.2020.3017727
# 57       10.3390/electronics9040568
# 58         10.1109/TMM.2023.3328180
# 59             10.3390/app142311130
#
#                                                 Title  \
# 0   FineDiving: A Fine-grained Dataset for Procedu...
# 1   LOGO: A Long-Form Video Dataset for Group Acti...
# 2   PECoP: Parameter Efficient Continual Pretraini...
# 3   Tai Chi Action Quality Assessment and Visual A...
# 4   FineParser: A Fine-Grained Spatio-Temporal Act...
# 5   Uncertainty-Aware Score Distribution Learning ...
# 6   Group-aware Contrastive Regression for Action ...
# 7   A Survey of Video-based Action Quality Assessment
# 8   Action Quality Assessment Across Multiple Actions
# 9   What and How Well You Performed? A Multitask L...
# 10                            Piano Skills Assessment
# 11  FineRehab: A Multi-modality and Multi-task Dat...
# 12  A Contrastive Learning Network for Performance...
# 13  AI Trainer: Autoencoder Based Approach for Squ...
# 14  A Video-Based Augmented Reality System for Hum...
# 15  Likert Scoring with Grade Decoupling for Long-...
# 16                   Learning to Score Olympic Events
# 17  Narrative Action Evaluation with Prompt-Guided...
# 18  Improving action quality assessment with acros...
# 19  Hierarchical Graph Convolutional Networks for ...
# 20  The Establishment of a precise intelligent eva...
# 21  A Figure Skating Jumping Dataset for Replay-Gu...
# 22  Prior Knowledge-guided Hierarchical Action Qua...
# 23  Fine-Grained Spatio-Temporal Parsing Network f...
# 24  A Novel Model for Intelligent Pull-Ups Test Ba...
# 25  Semi-Supervised Action Quality Assessment With...
# 26  Skeleton-Based Action Quality Assessment via P...
# 27  Action Quality Assessment with Temporal Parsin...
# 28  Improving Action Quality Assessment Using Weig...
# 29  TSA-Net: Tube Self-Attention Network for Actio...
# 30  Towards Improved and Interpretable Action Qual...
# 31  Skeleton Based Action Quality Assessment of Fi...
# 32  ACTION QUALITY ASSESSMENT WITH IGNORING SCENE ...
# 33  A Multi-dimensional Aesthetic Quality Assessme...
# 34  ATQAM/MAST'20: Joint Workshop on Aesthetic and...
# 35  Hybrid Dynamic-static Context-aware Attention ...
# 36       An Asymmetric Modeling for Action Assessment
# 37  ScoringNet: Learning Key Fragment for Action Q...
# 38  End-to-end learning for action quality assessment
# 39                   Assessing the quality of actions
# 40  Auto-encoding score distribution regression fo...
# 41  Two-path target-aware contrastive regression f...
# 42  Gaussian guided frame sequence encoder network...
# 43  Self-Supervised Sub-Action Parsing Network for...
# 44  Assessing action quality with semantic-sequenc...
# 45  Multi-skeleton structures graph convolutional ...
# 46  Learning Sparse Temporal Video Mapping for Act...
# 47               Multimodal Action Quality Assessment
# 48  Temporal attention learning for action quality...
# 49  ResFNN: Residual Structure-Based Feedforward N...
# 50  NAAQA: A Neural Architecture for Acoustic Ques...
# 51  Skeleton-based deep pose feature learning for ...
# 52  Procedure-Aware Action Quality Assessment: Dat...
# 53  Functional movement screen dataset collected w...
# 54  Automatic Modelling for Interactive Action Ass...
# 55  A Survey of Vision-Based Human Action Evaluati...
# 56  Action Quality Assessment Using Siamese Networ...
# 57  Learning Effective Skeletal Representations on...
# 58  Learning Semantics-Guided Representations for ...
# 59  Evaluation of Human Action Based on Feature-We...
#
#                                               Authors  Year  \
# 0       J. Xu; Y. Rao; X. Yu; G. Chen; J. Zhou; J. Lu  2022
# 1   S. Zhang; W. Dai; S. Wang; X. Shen; J. Lu; J. ...  2023
# 2      A. Dadashzadeh; S. Duan; A. Whone; M. Mirmehdi  2024
# 3      J. Li; H. Hu; Q. Xing; X. Wang; J. Li; Y. Shen  2022
# 4            J. Xu; S. Yin; G. Zhao; Z. Wang; Y. Peng  2024
# 5   Y. Tang; Z. Ni; J. Zhou; D. Zhang; J. Lu; Y. W...  2020
# 6              X. Yu; Y. Rao; W. Zhao; J. Lu; J. Zhou  2021
# 7   S. Wang; D. Yang; P. Zhai; Q. Yu; T. Suo; Z. S...  2021
# 8                                P. Parmar; B. Morris  2019
# 9                             P. Parmar; B. T. Morris  2019
# 10                     P. Parmar; J. Reddy; B. Morris  2021
# 11  J. Li; J. Xue; R. Cao; X. Du; S. Mo; K. Ran; Z...  2024
# 12            L. Yao; Q. Lei; H. Zhang; J. Du; S. Gao  2023
# 13  M. Chariar; S. Rao; A. Irani; S. Suresh; C. S....  2023
# 14  K. Zhou; R. Cai; Y. Ma; Q. Tan; X. Wang; J. Li...  2023
# 15                   A. Xu; L. -A. Zeng; W. -S. Zheng  2022
# 16                            P. Parmar; B. T. Morris  2017
# 17  S. Zhang; S. Bai; G. Chen; L. Chen; J. Lu; J. ...  2024
# 18               P., Lian, Puxiang; Z., Shao, Zhigang  2023
# 19  K., Zhou, Kanglei; Y., Ma, Yue; H.P., Shum, Hu...  2023
# 20  N., Hao, Ning; S., Ruan, Sihan; Y., Song, Yihe...  2023
# 21  Y., Liu, Yanchao; X., Cheng, Xina; T., Ikenaga...  2023
# 22    H., Zhou, Haoyang; T., Hou, Teng; J., Li, Jitao  2023
# 23  G.A., Kumie, Gedamu Alemu; Y., Ji, Yanli; Y., ...  2023
# 24  G., Liu, Guozhong; J., Wang, Jian; Z., Zhang, ...  2023
# 25  S., Zhang, Shaojie; J., Pan, Jiahui; J., Gao, ...  2022
# 26  X., Wang, Xinyu; J., Li, Jianwei; H., Hu, Haiqing  2022
# 27  Y., Bai, Yang; D., Zhou, Desen; S., Zhang, Son...  2022
# 28  S., Farabi, Shafkat; H., Himel, Hasibul; F., G...  2022
# 29  S., Wang, Shunli; D., Yang, Dingkang; P., Zhai...  2021
# 30  K., Roditakis, Konstantinos; A., Makris, Alexa...  2021
# 31  H., Li, Huiying; Q., Lei, Qing; H., Zhang, Hon...  2021
# 32  T., Nagai, Takasuke; S., Takeda, Shoichiro; M....  2021
# 33  T., Wang, Tao; W., Sun, Wei; X., Min, Xiongkuo...  2021
# 34  T., Guha, Tanaya; V., Hosu, Vlad; D., Saupe, D...  2020
# 35  L., Zeng, Lingan; F., Hong, Fating; W., Zheng,...  2020
# 36  J., Gao, Jibin; W., Zheng, Wei-Shi; J., Pan, J...  2020
# 37  Y., Li, Yongjun; X., Chai, Xiujuan; X., Chen, ...  2019
# 38  Y., Li, Yongjun; X., Chai, Xiujuan; X., Chen, ...  2018
# 39  H., Pirsiavash, Hamed; C., Vondrick, Carl; A.,...  2014
# 40  Zhang, Boyu; Chen, Jiayuan; Xu, Yinfei; Zhang,...  2023
# 41  Ke, Xiao; Xu, Huangbiao; Lin, Xiaofeng; Guo, W...  2024
# 42  Li, Ming-Zhe; Zhang, Hong-Bo; Dong, Li-Jia; Le...  2023
# 43  Gedamu, Kumie; Ji, Yanli; Yang, Yang; Shao, Ji...  2024
# 44                           Huang, Feng; Li, Jianjun  2024
# 45  Lei, Qing; Li, Huiying; Zhang, Hongbo; Du, Jix...  2023
# 46  Zahan, Sania; Hassan, Ghulam Mubashar; Mian, A...  2024
# 47                      Zeng, Ling-An; Zheng, Wei-Shi  2024
# 48              Lei, Qing; Zhang, Hongbo; Du, Jixiang  2021
# 49  Gao, Honghao; Yu, Si; Iqbal, Muddesar; Guizani...  2024
# 50   Abdelnour, Jerome; Rouat, Jean; Salvi, Giampiero  2023
# 51  Li, Huiying; Lei, Qing; Zhang, Hongbo; Du, Jix...  2022
# 52   Xu, Jinglin; Rao, Yongming; Zhou, Jie; Lu, Jiwen  2024
# 53  Xing, Qing-Jun; Shen, Yuan-Yuan; Cao, Run; Zon...  2022
# 54  Gao, Jibin; Pan, Jia-Hui; Zhang, Shao-Jie; Zhe...  2023
# 55  Lei, Qing; Du, Ji-Xiang; Zhang, Hong-Bo; Ye, S...  2019
# 56      Jain, Hiteshi; Harit, Gaurav; Sharma, Avinash  2021
# 57  Lei, Qing; Zhang, Hong-Bo; Du, Ji-Xiang; Hsiao...  2020
# 58          Du, Zexing; He, Di; Wang, Xue; Wang, Qing  2024
# 59   Yan, Mingdie; Liu, Xia; Li, Zhaoyang; Guo, Naiyu  2024
#
#                                              Abstract Include  \
# 0   Most existing action quality assessment method...     yes
# 1   Action quality assessment (AQA) has become an ...     yes
# 2   The limited availability of labelled data in A...     yes
# 3   Visual-based human action analysis is an impor...     yes
# 4   Existing action quality assessment (AQA) metho...     yes
# 5   Assessing action quality from videos has attra...     yes
# 6   Assessing action quality is challenging due to...     yes
# 7   Human action recognition and analysis have gre...      no
# 8   Can learning to measure the quality of an acti...     yes
# 9   Can performance on the task of action quality ...     yes
# 10  Can a computer determine a piano player’s skil...     yes
# 11  The assessment of rehabilitation exercises for...     yes
# 12  Human activity analysis in the legal monitorin...     yes
# 13  Artificial intelligence and computer vision ha...   maybe
# 14  As the most common idiopathic inflammatory myo...   maybe
# 15  Long-term action quality assessment is a task ...   maybe
# 16  Estimating action quality, the process of assi...   maybe
# 17  In this paper, we investigate a new problem ca...     yes
# 18  Action quality assessment is a significant res...     yes
# 19  Action quality assessment (AQA) automatically ...     yes
# 20  The introduction of action quality assessment ...     yes
# 21  In competitive sports, judges often scrutinize...     yes
# 22  Recently, there has been a growing interest in...     yes
# 23  Action Quality Assessment (AQA) plays an impor...     yes
# 24  Applying computer vision and machine learning ...     yes
# 25  Action Quality Assessment aims to evaluate how...     yes
# 26  Human action quality assessment (AQA) recently...     yes
# 27  Action Quality Assessment(AQA) is important fo...   maybe
# 28  Action quality assessment (AQA) aims at automa...     yes
# 29  In recent years, assessing action quality from...     yes
# 30  Action Quality Assessment (AQA) is a video und...     yes
# 31  Action quality assessment(AQA) aims at achievi...     yes
# 32  We propose an action quality assessment (AQA) ...   maybe
# 33  With the development of the game industry and ...      no
# 34  The Joint Workshop on Aesthetic and Technical ...      no
# 35  The objective of action quality assessment is ...     yes
# 36  Action assessment is a task of assessing the p...     yes
# 37  Nowadays, scoring athletes’ performance in ski...   maybe
# 38  Nowadays, action quality assessment has attrac...   maybe
# 39  While recent advances in computer vision have ...     yes
# 40  Assessing the quality of actions in videos is ...     yes
# 41  Action quality assessment (AQA) is a challengi...     yes
# 42  Can a computer evaluate an athlete's performan...     yes
# 43  Semi-supervised Action Quality Assessment (AQA...     yes
# 44  Action Quality Assessment (AQA) is a critical ...     yes
# 45  In most existing action quality assessment (AQ...     yes
# 46  Automated athlete performance measurement from...     yes
# 47  Action quality assessment (AQA) is to assess h...     yes
# 48  This paper proposes an end-to-end temporal att...     yes
# 49  With the development of artificial intelligenc...     yes
# 50  The goal of the Acoustic Question Answering (A...      no
# 51  Most of the existing Action Quality Assessment...     yes
# 52  In this paper, we investigate the problem of p...     yes
# 53  This paper presents a dataset for vision-based...     yes
# 54  Action assessment, the task of visually assess...     yes
# 55  The fields of human activity analysis have rec...      no
# 56  Automated vision-based score estimation models...     yes
# 57  In this paper, we propose an integrated action...     yes
# 58  This paper explores semantic-aware representat...     yes
# 59  Action evaluation can automatically detect abn...     yes
#
#                                                Reason  \
# 0   The paper introduces a new dataset for human a...
# 1   The paper introduces a new dataset for group a...
# 2   The paper introduces a new dataset (PD4T) and ...
# 3   The paper introduces a new dataset for human a...
# 4   The paper introduces new annotations for an ex...
# 5   The paper uses existing public datasets for hu...
# 6   The paper uses existing public datasets for hu...
# 7   The article is a survey paper, which is an exc...
# 8   The paper introduces a new dataset for human a...
# 9   The paper introduces a new dataset for human a...
# 10  The paper introduces a new dataset for human a...
# 11  The paper introduces a new dataset for human a...
# 12  The paper uses existing public datasets for hu...
# 13  The paper mentions using their own dataset for...
# 14  The paper mentions using a 'JDM dataset' for h...
# 15  The paper uses unnamed datasets for human AQA....
# 16  The paper discusses and uses data for human AQ...
# 17  The paper creates new annotations for existing...
# 18  The paper uses an existing public dataset for ...
# 19  The paper uses existing public datasets for hu...
# 20  The paper proposes a novel method for action q...
# 21  The paper introduces a new dataset for action ...
# 22  The paper proposes a new network structure for...
# 23  The paper proposes a new network for action qu...
# 24  The paper describes a model for intelligent pu...
# 25  The paper addresses semi-supervised action qua...
# 26  The paper proposes a skeleton-based method for...
# 27  The paper mentions using three public AQA benc...
# 28  The paper proposes a new technique for action ...
# 29  The paper proposes a new network for action qu...
# 30  The paper presents a method for action quality...
# 31  The paper proposes a skeleton-based method for...
# 32  The paper mentions evaluating its method on 'a...
# 33  The paper focuses on aesthetic quality assessm...
# 34  The article is a summary of a joint workshop, ...
# 35  The paper proposes a new network for action qu...
# 36  The paper proposes a model for action assessme...
# 37  The paper mentions achieving state-of-the-art ...
# 38  The paper mentions conducting experiments on '...
# 39  The paper introduces a framework for assessing...
# 40  The paper is about vision-based human Action Q...
# 41  The paper focuses on vision-based human Action...
# 42  The paper proposes a method for vision-based h...
# 43  The paper addresses vision-based human Action ...
# 44  The paper is about vision-based human Action Q...
# 45  The paper proposes a method for vision-based h...
# 46  The paper addresses vision-based human Action ...
# 47  The paper is about vision-based human Action Q...
# 48  The paper proposes a method for vision-based h...
# 49  The paper is about vision-based human Action Q...
# 50  The paper is about Acoustic Question Answering...
# 51  The paper proposes a method for vision-based h...
# 52  The paper addresses vision-based human Action ...
# 53  The paper presents a new multimodal and multiv...
# 54  The paper is about vision-based human Action Q...
# 55  The paper is a survey, which is an exclusion c...
# 56  The paper proposes a vision-based model for hu...
# 57  The paper is about vision-based human Action Q...
# 58  The paper addresses vision-based human Action ...
# 59  The paper is about vision-based human action e...
#
#                                       Data Source
# 0                                      FineDiving
# 1                                            LOGO
# 2                 JIGSAWS;MTL-AQA;FineDiving;PD4T
# 3                                       TaiChi-24
# 4                                   FineDiving-HM
# 5                                   AQA-7;MTL-AQA
# 6                           AQA-7;MTL-AQA;JIGSAWS
# 7                                             NaN
# 8                                             NaN
# 9                                         MTL-AQA
# 10                        Piano Skills Assessment
# 11                                      FineRehab
# 12                                 UI-PRMD;KIMORE
# 13                                            NaN
# 14                                            NaN
# 15                                            NaN
# 16                                            NaN
# 17                                MTL-AQA;FineGym
# 18                                     FineDiving
# 19                          AQA-7;MTL-AQA;JIGSAWS
# 20                                      UNLV-Dive
# 21                                           RFSJ
# 22                                          AQA-7
# 23                       FineDiving;AQA-7;MTL-AQA
# 24                                       Pull-ups
# 25                    MTL-AQA;Rhythmic Gymnastics
# 26                      UMONS-TAICHI;Walking gait
# 27                                            NaN
# 28                                        MTL-AQA
# 29                            AQA-7;MTL-AQA;FR-FS
# 30                                        MTL-AQA
# 31                                      MIT-skate
# 32                                            NaN
# 33                                            NaN
# 34                                            NaN
# 35                            Rhythmic Gymnastics
# 36                           JIGSAWS;TASD-2;AQA-7
# 37                                            NaN
# 38                                            NaN
# 39                                 Olympic Sports
# 40                          AQA-7;MTL-AQA;JIGSAWS
# 41               MTL-AQA;FineDiving;AQA-7;JIGSAWS
# 42                                  AQA-7;MTL-AQA
# 43  MTL-AQA;FineDiving;Rhythmic Gymnastics;FineFS
# 44                                UNLV-Dive;AQA-7
# 45                  MIT-skate;Rhythmic Gymnastics
# 46                                   AGF-Olympics
# 47                                            NaN
# 48                                          AQA-7
# 49                          AQA-7;MTL-AQA;JIGSAWS
# 50                                            NaN
# 51                                MIT-skate;FIS-V
# 52                         FineDiving;FineDiving+
# 53                     Functional Movement Screen
# 54                      JIGSAWS;TASD-2;PaSk;AQA-7
# 55                                            NaN
# 56                                            NaN
# 57       MIT Olympic Scoring;UNLV Olympic Scoring
# 58                                      OlympicFS
# 59                                            NaN

# %%
df_validation = df_validation[df_validation["Include"] != "no"].reset_index(drop=True)
df_validation
# Out:
#                                 DOI  \
# 0      10.1109/CVPR52688.2022.00296
# 1      10.1109/CVPR52729.2023.00238
# 2      10.1109/WACV57701.2024.00012
# 3    10.1109/MMSP55362.2022.9949464
# 4      10.1109/CVPR52733.2024.01386
# 5      10.1109/CVPR42600.2020.00986
# 6      10.1109/ICCV48922.2021.00782
# 7           10.1109/WACV.2019.00161
# 8           10.1109/CVPR.2019.00039
# 9    10.1109/MMSP53017.2021.9733638
# 10    10.1109/CVPRW63382.2024.00324
# 11       10.1109/TNSRE.2023.3317411
# 12      10.1109/ACCESS.2023.3316009
# 13        10.1109/TVCG.2023.3247092
# 14     10.1109/CVPR52688.2022.00323
# 15            10.1109/CVPRW.2017.16
# 16     10.1109/CVPR52733.2024.01744
# 17       10.1007/s10489-023-05166-3
# 18       10.1109/TCSVT.2023.3281413
# 19    10.1016/j.heliyon.2023.e21361
# 20          10.1145/3581783.3613774
# 21  10.1088/1742-6596/2632/1/012027
# 22         10.1109/TIP.2023.3331212
# 23             10.1155/2023/3649217
# 24       10.1109/TCSVT.2022.3143549
# 25     10.1007/978-3-031-18913-5_17
# 26     10.1007/978-3-031-19772-7_25
# 27     10.1007/978-3-031-04881-4_46
# 28          10.1145/3474085.3475438
# 29          10.1145/3453892.3461624
# 30     10.1109/ITME53901.2021.00048
# 31   10.1109/ICIP42928.2021.9506257
# 32          10.1145/3394171.3413560
# 33     10.1007/978-3-030-58577-8_14
# 34     10.1007/978-3-030-20876-9_10
# 35     10.1007/978-3-030-00767-6_12
# 36     10.1007/978-3-319-10599-4_36
# 37       10.1007/s00521-023-09068-w
# 38        10.1016/j.ins.2024.120347
# 39       10.1007/s40747-022-00892-6
# 40         10.1109/TIP.2024.3468870
# 41       10.1007/s10489-024-05349-6
# 42       10.1007/s10489-023-04613-5
# 43         10.1109/TIM.2024.3398072
# 44         10.1109/TIP.2024.3362135
# 45       10.1007/s11760-021-01890-w
# 46         10.1109/TCE.2024.3482560
# 47      10.1016/j.jvcir.2022.103625
# 48       10.1007/s11263-024-02146-z
# 49       10.1038/s41597-022-01188-7
# 50       10.1007/s11263-022-01695-5
# 51       10.1109/TCSVT.2020.3017727
# 52       10.3390/electronics9040568
# 53         10.1109/TMM.2023.3328180
# 54             10.3390/app142311130
#
#                                                 Title  \
# 0   FineDiving: A Fine-grained Dataset for Procedu...
# 1   LOGO: A Long-Form Video Dataset for Group Acti...
# 2   PECoP: Parameter Efficient Continual Pretraini...
# 3   Tai Chi Action Quality Assessment and Visual A...
# 4   FineParser: A Fine-Grained Spatio-Temporal Act...
# 5   Uncertainty-Aware Score Distribution Learning ...
# 6   Group-aware Contrastive Regression for Action ...
# 7   Action Quality Assessment Across Multiple Actions
# 8   What and How Well You Performed? A Multitask L...
# 9                             Piano Skills Assessment
# 10  FineRehab: A Multi-modality and Multi-task Dat...
# 11  A Contrastive Learning Network for Performance...
# 12  AI Trainer: Autoencoder Based Approach for Squ...
# 13  A Video-Based Augmented Reality System for Hum...
# 14  Likert Scoring with Grade Decoupling for Long-...
# 15                   Learning to Score Olympic Events
# 16  Narrative Action Evaluation with Prompt-Guided...
# 17  Improving action quality assessment with acros...
# 18  Hierarchical Graph Convolutional Networks for ...
# 19  The Establishment of a precise intelligent eva...
# 20  A Figure Skating Jumping Dataset for Replay-Gu...
# 21  Prior Knowledge-guided Hierarchical Action Qua...
# 22  Fine-Grained Spatio-Temporal Parsing Network f...
# 23  A Novel Model for Intelligent Pull-Ups Test Ba...
# 24  Semi-Supervised Action Quality Assessment With...
# 25  Skeleton-Based Action Quality Assessment via P...
# 26  Action Quality Assessment with Temporal Parsin...
# 27  Improving Action Quality Assessment Using Weig...
# 28  TSA-Net: Tube Self-Attention Network for Actio...
# 29  Towards Improved and Interpretable Action Qual...
# 30  Skeleton Based Action Quality Assessment of Fi...
# 31  ACTION QUALITY ASSESSMENT WITH IGNORING SCENE ...
# 32  Hybrid Dynamic-static Context-aware Attention ...
# 33       An Asymmetric Modeling for Action Assessment
# 34  ScoringNet: Learning Key Fragment for Action Q...
# 35  End-to-end learning for action quality assessment
# 36                   Assessing the quality of actions
# 37  Auto-encoding score distribution regression fo...
# 38  Two-path target-aware contrastive regression f...
# 39  Gaussian guided frame sequence encoder network...
# 40  Self-Supervised Sub-Action Parsing Network for...
# 41  Assessing action quality with semantic-sequenc...
# 42  Multi-skeleton structures graph convolutional ...
# 43  Learning Sparse Temporal Video Mapping for Act...
# 44               Multimodal Action Quality Assessment
# 45  Temporal attention learning for action quality...
# 46  ResFNN: Residual Structure-Based Feedforward N...
# 47  Skeleton-based deep pose feature learning for ...
# 48  Procedure-Aware Action Quality Assessment: Dat...
# 49  Functional movement screen dataset collected w...
# 50  Automatic Modelling for Interactive Action Ass...
# 51  Action Quality Assessment Using Siamese Networ...
# 52  Learning Effective Skeletal Representations on...
# 53  Learning Semantics-Guided Representations for ...
# 54  Evaluation of Human Action Based on Feature-We...
#
#                                               Authors  Year  \
# 0       J. Xu; Y. Rao; X. Yu; G. Chen; J. Zhou; J. Lu  2022
# 1   S. Zhang; W. Dai; S. Wang; X. Shen; J. Lu; J. ...  2023
# 2      A. Dadashzadeh; S. Duan; A. Whone; M. Mirmehdi  2024
# 3      J. Li; H. Hu; Q. Xing; X. Wang; J. Li; Y. Shen  2022
# 4            J. Xu; S. Yin; G. Zhao; Z. Wang; Y. Peng  2024
# 5   Y. Tang; Z. Ni; J. Zhou; D. Zhang; J. Lu; Y. W...  2020
# 6              X. Yu; Y. Rao; W. Zhao; J. Lu; J. Zhou  2021
# 7                                P. Parmar; B. Morris  2019
# 8                             P. Parmar; B. T. Morris  2019
# 9                      P. Parmar; J. Reddy; B. Morris  2021
# 10  J. Li; J. Xue; R. Cao; X. Du; S. Mo; K. Ran; Z...  2024
# 11            L. Yao; Q. Lei; H. Zhang; J. Du; S. Gao  2023
# 12  M. Chariar; S. Rao; A. Irani; S. Suresh; C. S....  2023
# 13  K. Zhou; R. Cai; Y. Ma; Q. Tan; X. Wang; J. Li...  2023
# 14                   A. Xu; L. -A. Zeng; W. -S. Zheng  2022
# 15                            P. Parmar; B. T. Morris  2017
# 16  S. Zhang; S. Bai; G. Chen; L. Chen; J. Lu; J. ...  2024
# 17               P., Lian, Puxiang; Z., Shao, Zhigang  2023
# 18  K., Zhou, Kanglei; Y., Ma, Yue; H.P., Shum, Hu...  2023
# 19  N., Hao, Ning; S., Ruan, Sihan; Y., Song, Yihe...  2023
# 20  Y., Liu, Yanchao; X., Cheng, Xina; T., Ikenaga...  2023
# 21    H., Zhou, Haoyang; T., Hou, Teng; J., Li, Jitao  2023
# 22  G.A., Kumie, Gedamu Alemu; Y., Ji, Yanli; Y., ...  2023
# 23  G., Liu, Guozhong; J., Wang, Jian; Z., Zhang, ...  2023
# 24  S., Zhang, Shaojie; J., Pan, Jiahui; J., Gao, ...  2022
# 25  X., Wang, Xinyu; J., Li, Jianwei; H., Hu, Haiqing  2022
# 26  Y., Bai, Yang; D., Zhou, Desen; S., Zhang, Son...  2022
# 27  S., Farabi, Shafkat; H., Himel, Hasibul; F., G...  2022
# 28  S., Wang, Shunli; D., Yang, Dingkang; P., Zhai...  2021
# 29  K., Roditakis, Konstantinos; A., Makris, Alexa...  2021
# 30  H., Li, Huiying; Q., Lei, Qing; H., Zhang, Hon...  2021
# 31  T., Nagai, Takasuke; S., Takeda, Shoichiro; M....  2021
# 32  L., Zeng, Lingan; F., Hong, Fating; W., Zheng,...  2020
# 33  J., Gao, Jibin; W., Zheng, Wei-Shi; J., Pan, J...  2020
# 34  Y., Li, Yongjun; X., Chai, Xiujuan; X., Chen, ...  2019
# 35  Y., Li, Yongjun; X., Chai, Xiujuan; X., Chen, ...  2018
# 36  H., Pirsiavash, Hamed; C., Vondrick, Carl; A.,...  2014
# 37  Zhang, Boyu; Chen, Jiayuan; Xu, Yinfei; Zhang,...  2023
# 38  Ke, Xiao; Xu, Huangbiao; Lin, Xiaofeng; Guo, W...  2024
# 39  Li, Ming-Zhe; Zhang, Hong-Bo; Dong, Li-Jia; Le...  2023
# 40  Gedamu, Kumie; Ji, Yanli; Yang, Yang; Shao, Ji...  2024
# 41                           Huang, Feng; Li, Jianjun  2024
# 42  Lei, Qing; Li, Huiying; Zhang, Hongbo; Du, Jix...  2023
# 43  Zahan, Sania; Hassan, Ghulam Mubashar; Mian, A...  2024
# 44                      Zeng, Ling-An; Zheng, Wei-Shi  2024
# 45              Lei, Qing; Zhang, Hongbo; Du, Jixiang  2021
# 46  Gao, Honghao; Yu, Si; Iqbal, Muddesar; Guizani...  2024
# 47  Li, Huiying; Lei, Qing; Zhang, Hongbo; Du, Jix...  2022
# 48   Xu, Jinglin; Rao, Yongming; Zhou, Jie; Lu, Jiwen  2024
# 49  Xing, Qing-Jun; Shen, Yuan-Yuan; Cao, Run; Zon...  2022
# 50  Gao, Jibin; Pan, Jia-Hui; Zhang, Shao-Jie; Zhe...  2023
# 51      Jain, Hiteshi; Harit, Gaurav; Sharma, Avinash  2021
# 52  Lei, Qing; Zhang, Hong-Bo; Du, Ji-Xiang; Hsiao...  2020
# 53          Du, Zexing; He, Di; Wang, Xue; Wang, Qing  2024
# 54   Yan, Mingdie; Liu, Xia; Li, Zhaoyang; Guo, Naiyu  2024
#
#                                              Abstract Include  \
# 0   Most existing action quality assessment method...     yes
# 1   Action quality assessment (AQA) has become an ...     yes
# 2   The limited availability of labelled data in A...     yes
# 3   Visual-based human action analysis is an impor...     yes
# 4   Existing action quality assessment (AQA) metho...     yes
# 5   Assessing action quality from videos has attra...     yes
# 6   Assessing action quality is challenging due to...     yes
# 7   Can learning to measure the quality of an acti...     yes
# 8   Can performance on the task of action quality ...     yes
# 9   Can a computer determine a piano player’s skil...     yes
# 10  The assessment of rehabilitation exercises for...     yes
# 11  Human activity analysis in the legal monitorin...     yes
# 12  Artificial intelligence and computer vision ha...   maybe
# 13  As the most common idiopathic inflammatory myo...   maybe
# 14  Long-term action quality assessment is a task ...   maybe
# 15  Estimating action quality, the process of assi...   maybe
# 16  In this paper, we investigate a new problem ca...     yes
# 17  Action quality assessment is a significant res...     yes
# 18  Action quality assessment (AQA) automatically ...     yes
# 19  The introduction of action quality assessment ...     yes
# 20  In competitive sports, judges often scrutinize...     yes
# 21  Recently, there has been a growing interest in...     yes
# 22  Action Quality Assessment (AQA) plays an impor...     yes
# 23  Applying computer vision and machine learning ...     yes
# 24  Action Quality Assessment aims to evaluate how...     yes
# 25  Human action quality assessment (AQA) recently...     yes
# 26  Action Quality Assessment(AQA) is important fo...   maybe
# 27  Action quality assessment (AQA) aims at automa...     yes
# 28  In recent years, assessing action quality from...     yes
# 29  Action Quality Assessment (AQA) is a video und...     yes
# 30  Action quality assessment(AQA) aims at achievi...     yes
# 31  We propose an action quality assessment (AQA) ...   maybe
# 32  The objective of action quality assessment is ...     yes
# 33  Action assessment is a task of assessing the p...     yes
# 34  Nowadays, scoring athletes’ performance in ski...   maybe
# 35  Nowadays, action quality assessment has attrac...   maybe
# 36  While recent advances in computer vision have ...     yes
# 37  Assessing the quality of actions in videos is ...     yes
# 38  Action quality assessment (AQA) is a challengi...     yes
# 39  Can a computer evaluate an athlete's performan...     yes
# 40  Semi-supervised Action Quality Assessment (AQA...     yes
# 41  Action Quality Assessment (AQA) is a critical ...     yes
# 42  In most existing action quality assessment (AQ...     yes
# 43  Automated athlete performance measurement from...     yes
# 44  Action quality assessment (AQA) is to assess h...     yes
# 45  This paper proposes an end-to-end temporal att...     yes
# 46  With the development of artificial intelligenc...     yes
# 47  Most of the existing Action Quality Assessment...     yes
# 48  In this paper, we investigate the problem of p...     yes
# 49  This paper presents a dataset for vision-based...     yes
# 50  Action assessment, the task of visually assess...     yes
# 51  Automated vision-based score estimation models...     yes
# 52  In this paper, we propose an integrated action...     yes
# 53  This paper explores semantic-aware representat...     yes
# 54  Action evaluation can automatically detect abn...     yes
#
#                                                Reason  \
# 0   The paper introduces a new dataset for human a...
# 1   The paper introduces a new dataset for group a...
# 2   The paper introduces a new dataset (PD4T) and ...
# 3   The paper introduces a new dataset for human a...
# 4   The paper introduces new annotations for an ex...
# 5   The paper uses existing public datasets for hu...
# 6   The paper uses existing public datasets for hu...
# 7   The paper introduces a new dataset for human a...
# 8   The paper introduces a new dataset for human a...
# 9   The paper introduces a new dataset for human a...
# 10  The paper introduces a new dataset for human a...
# 11  The paper uses existing public datasets for hu...
# 12  The paper mentions using their own dataset for...
# 13  The paper mentions using a 'JDM dataset' for h...
# 14  The paper uses unnamed datasets for human AQA....
# 15  The paper discusses and uses data for human AQ...
# 16  The paper creates new annotations for existing...
# 17  The paper uses an existing public dataset for ...
# 18  The paper uses existing public datasets for hu...
# 19  The paper proposes a novel method for action q...
# 20  The paper introduces a new dataset for action ...
# 21  The paper proposes a new network structure for...
# 22  The paper proposes a new network for action qu...
# 23  The paper describes a model for intelligent pu...
# 24  The paper addresses semi-supervised action qua...
# 25  The paper proposes a skeleton-based method for...
# 26  The paper mentions using three public AQA benc...
# 27  The paper proposes a new technique for action ...
# 28  The paper proposes a new network for action qu...
# 29  The paper presents a method for action quality...
# 30  The paper proposes a skeleton-based method for...
# 31  The paper mentions evaluating its method on 'a...
# 32  The paper proposes a new network for action qu...
# 33  The paper proposes a model for action assessme...
# 34  The paper mentions achieving state-of-the-art ...
# 35  The paper mentions conducting experiments on '...
# 36  The paper introduces a framework for assessing...
# 37  The paper is about vision-based human Action Q...
# 38  The paper focuses on vision-based human Action...
# 39  The paper proposes a method for vision-based h...
# 40  The paper addresses vision-based human Action ...
# 41  The paper is about vision-based human Action Q...
# 42  The paper proposes a method for vision-based h...
# 43  The paper addresses vision-based human Action ...
# 44  The paper is about vision-based human Action Q...
# 45  The paper proposes a method for vision-based h...
# 46  The paper is about vision-based human Action Q...
# 47  The paper proposes a method for vision-based h...
# 48  The paper addresses vision-based human Action ...
# 49  The paper presents a new multimodal and multiv...
# 50  The paper is about vision-based human Action Q...
# 51  The paper proposes a vision-based model for hu...
# 52  The paper is about vision-based human Action Q...
# 53  The paper addresses vision-based human Action ...
# 54  The paper is about vision-based human action e...
#
#                                       Data Source
# 0                                      FineDiving
# 1                                            LOGO
# 2                 JIGSAWS;MTL-AQA;FineDiving;PD4T
# 3                                       TaiChi-24
# 4                                   FineDiving-HM
# 5                                   AQA-7;MTL-AQA
# 6                           AQA-7;MTL-AQA;JIGSAWS
# 7                                             NaN
# 8                                         MTL-AQA
# 9                         Piano Skills Assessment
# 10                                      FineRehab
# 11                                 UI-PRMD;KIMORE
# 12                                            NaN
# 13                                            NaN
# 14                                            NaN
# 15                                            NaN
# 16                                MTL-AQA;FineGym
# 17                                     FineDiving
# 18                          AQA-7;MTL-AQA;JIGSAWS
# 19                                      UNLV-Dive
# 20                                           RFSJ
# 21                                          AQA-7
# 22                       FineDiving;AQA-7;MTL-AQA
# 23                                       Pull-ups
# 24                    MTL-AQA;Rhythmic Gymnastics
# 25                      UMONS-TAICHI;Walking gait
# 26                                            NaN
# 27                                        MTL-AQA
# 28                            AQA-7;MTL-AQA;FR-FS
# 29                                        MTL-AQA
# 30                                      MIT-skate
# 31                                            NaN
# 32                            Rhythmic Gymnastics
# 33                           JIGSAWS;TASD-2;AQA-7
# 34                                            NaN
# 35                                            NaN
# 36                                 Olympic Sports
# 37                          AQA-7;MTL-AQA;JIGSAWS
# 38               MTL-AQA;FineDiving;AQA-7;JIGSAWS
# 39                                  AQA-7;MTL-AQA
# 40  MTL-AQA;FineDiving;Rhythmic Gymnastics;FineFS
# 41                                UNLV-Dive;AQA-7
# 42                  MIT-skate;Rhythmic Gymnastics
# 43                                   AGF-Olympics
# 44                                            NaN
# 45                                          AQA-7
# 46                          AQA-7;MTL-AQA;JIGSAWS
# 47                                MIT-skate;FIS-V
# 48                         FineDiving;FineDiving+
# 49                     Functional Movement Screen
# 50                      JIGSAWS;TASD-2;PaSk;AQA-7
# 51                                            NaN
# 52       MIT Olympic Scoring;UNLV Olympic Scoring
# 53                                      OlympicFS
# 54                                            NaN

# %%
df_final = df_validation[df_validation["Data Source"].isna()].reset_index(drop=True)
df_final
# Out:
#                                DOI  \
# 0          10.1109/WACV.2019.00161
# 1      10.1109/ACCESS.2023.3316009
# 2        10.1109/TVCG.2023.3247092
# 3     10.1109/CVPR52688.2022.00323
# 4            10.1109/CVPRW.2017.16
# 5     10.1007/978-3-031-19772-7_25
# 6   10.1109/ICIP42928.2021.9506257
# 7     10.1007/978-3-030-20876-9_10
# 8     10.1007/978-3-030-00767-6_12
# 9         10.1109/TIP.2024.3362135
# 10      10.1109/TCSVT.2020.3017727
# 11            10.3390/app142311130
#
#                                                 Title  \
# 0   Action Quality Assessment Across Multiple Actions
# 1   AI Trainer: Autoencoder Based Approach for Squ...
# 2   A Video-Based Augmented Reality System for Hum...
# 3   Likert Scoring with Grade Decoupling for Long-...
# 4                    Learning to Score Olympic Events
# 5   Action Quality Assessment with Temporal Parsin...
# 6   ACTION QUALITY ASSESSMENT WITH IGNORING SCENE ...
# 7   ScoringNet: Learning Key Fragment for Action Q...
# 8   End-to-end learning for action quality assessment
# 9                Multimodal Action Quality Assessment
# 10  Action Quality Assessment Using Siamese Networ...
# 11  Evaluation of Human Action Based on Feature-We...
#
#                                               Authors  Year  \
# 0                                P. Parmar; B. Morris  2019
# 1   M. Chariar; S. Rao; A. Irani; S. Suresh; C. S....  2023
# 2   K. Zhou; R. Cai; Y. Ma; Q. Tan; X. Wang; J. Li...  2023
# 3                    A. Xu; L. -A. Zeng; W. -S. Zheng  2022
# 4                             P. Parmar; B. T. Morris  2017
# 5   Y., Bai, Yang; D., Zhou, Desen; S., Zhang, Son...  2022
# 6   T., Nagai, Takasuke; S., Takeda, Shoichiro; M....  2021
# 7   Y., Li, Yongjun; X., Chai, Xiujuan; X., Chen, ...  2019
# 8   Y., Li, Yongjun; X., Chai, Xiujuan; X., Chen, ...  2018
# 9                       Zeng, Ling-An; Zheng, Wei-Shi  2024
# 10      Jain, Hiteshi; Harit, Gaurav; Sharma, Avinash  2021
# 11   Yan, Mingdie; Liu, Xia; Li, Zhaoyang; Guo, Naiyu  2024
#
#                                              Abstract Include  \
# 0   Can learning to measure the quality of an acti...     yes
# 1   Artificial intelligence and computer vision ha...   maybe
# 2   As the most common idiopathic inflammatory myo...   maybe
# 3   Long-term action quality assessment is a task ...   maybe
# 4   Estimating action quality, the process of assi...   maybe
# 5   Action Quality Assessment(AQA) is important fo...   maybe
# 6   We propose an action quality assessment (AQA) ...   maybe
# 7   Nowadays, scoring athletes’ performance in ski...   maybe
# 8   Nowadays, action quality assessment has attrac...   maybe
# 9   Action quality assessment (AQA) is to assess h...     yes
# 10  Automated vision-based score estimation models...     yes
# 11  Action evaluation can automatically detect abn...     yes
#
#                                                Reason Data Source
# 0   The paper introduces a new dataset for human a...         NaN
# 1   The paper mentions using their own dataset for...         NaN
# 2   The paper mentions using a 'JDM dataset' for h...         NaN
# 3   The paper uses unnamed datasets for human AQA....         NaN
# 4   The paper discusses and uses data for human AQ...         NaN
# 5   The paper mentions using three public AQA benc...         NaN
# 6   The paper mentions evaluating its method on 'a...         NaN
# 7   The paper mentions achieving state-of-the-art ...         NaN
# 8   The paper mentions conducting experiments on '...         NaN
# 9   The paper is about vision-based human Action Q...         NaN
# 10  The paper proposes a vision-based model for hu...         NaN
# 11  The paper is about vision-based human action e...         NaN

# %%
unique_sources = df_validation['Data Source'].dropna().unique().tolist()
unique_sources = [source.strip() for item in unique_sources for source in item.split(';')]
unique_sources = list(set(unique_sources))

print(f"The total number of sources is: {len(unique_sources)}\n")
unique_sources
# Out:
# The total number of sources is: 32
# ['Pull-ups',
#  'FR-FS',
#  'Olympic Sports',
#  'UMONS-TAICHI',
#  'AQA-7',
#  'FineRehab',
#  'PD4T',
#  'JIGSAWS',
#  'FIS-V',
#  'LOGO',
#  'Functional Movement Screen',
#  'UNLV-Dive',
#  'FineDiving',
#  'TASD-2',
#  'Walking gait',
#  'KIMORE',
#  'TaiChi-24',
#  'UNLV Olympic Scoring',
#  'MTL-AQA',
#  'FineGym',
#  'MIT-skate',
#  'PaSk',
#  'MIT Olympic Scoring',
#  'UI-PRMD',
#  'FineDiving-HM',
#  'Rhythmic Gymnastics',
#  'FineDiving+',
#  'OlympicFS',
#  'Piano Skills Assessment',
#  'RFSJ',
#  'AGF-Olympics',
#  'FineFS']

# %%
unique_sources.sort(key=len)
filtered_sources = []

for source in unique_sources:
    if not any(source.startswith(existing) for existing in filtered_sources):
        filtered_sources.append(source)

print(f"The total number of filtered sources is: {len(filtered_sources)}\n")
filtered_sources
# Out:
# The total number of filtered sources is: 30
# ['PD4T',
#  'LOGO',
#  'PaSk',
#  'RFSJ',
#  'FR-FS',
#  'AQA-7',
#  'FIS-V',
#  'TASD-2',
#  'KIMORE',
#  'FineFS',
#  'JIGSAWS',
#  'MTL-AQA',
#  'FineGym',
#  'UI-PRMD',
#  'Pull-ups',
#  'FineRehab',
#  'UNLV-Dive',
#  'TaiChi-24',
#  'MIT-skate',
#  'OlympicFS',
#  'FineDiving',
#  'UMONS-TAICHI',
#  'Walking gait',
#  'AGF-Olympics',
#  'Olympic Sports',
#  'MIT Olympic Scoring',
#  'Rhythmic Gymnastics',
#  'UNLV Olympic Scoring',
#  'Piano Skills Assessment',
#  'Functional Movement Screen']

# %%
original_list = [
    'MIT Olympic Scoring',
    'JIGSAWS',
    'UNLV-vault',
    'UNLV-skating',
    'UNLV-diving',
    'UMONS-TAICHI',
    'Walking gait',
    'UI-PRMD',
    'AQA-7',
    'MTL-AQA',
    'FIS-V',
    'Rhythmic Gymnastics',
    'TASD-2',
    'Piano Skills Assessment',
    'FineDiving',
    'NETS',
    'PaSk',
    'FineFS',
    'MMASD',
    'LOGO'
]

print(f"The total number of original sources is: {len(original_list)}\n")
# Out:
# The total number of original sources is: 20

# %%
set_filtered = set(filtered_sources)
set_original = set(original_list)

# Elements in common
common_elements = set_filtered & set_original

# Elements unique to each list
only_in_filtered = set_filtered - set_original
only_in_original = set_original - set_filtered


print("Elements in common:", common_elements)
print("Number of elements in common:", len(common_elements))

print("\nElements in filtered_sources but not in original_list:", only_in_filtered)
print("Number:", len(only_in_filtered))

print("\nElements in original_list but not in filtered_sources:", only_in_original)
print("Number:", len(only_in_original))
# Out:
# Elements in common: {'LOGO', 'FineFS', 'Rhythmic Gymnastics', 'MTL-AQA', 'JIGSAWS', 'UMONS-TAICHI', 'Piano Skills Assessment', 'FineDiving', 'TASD-2', 'Walking gait', 'PaSk', 'AQA-7', 'MIT Olympic Scoring', 'UI-PRMD', 'FIS-V'}
# Number of elements in common: 15
#
# Elements in filtered_sources but not in original_list: {'Pull-ups', 'FR-FS', 'Olympic Sports', 'Functional Movement Screen', 'UNLV-Dive', 'TaiChi-24', 'UNLV Olympic Scoring', 'OlympicFS', 'RFSJ', 'FineGym', 'AGF-Olympics', 'MIT-skate', 'KIMORE', 'FineRehab', 'PD4T'}
# Number: 15
#
# Elements in original_list but not in filtered_sources: {'MMASD', 'UNLV-diving', 'UNLV-vault', 'NETS', 'UNLV-skating'}
# Number: 5

# %% [markdown]
# # Experiments
